# %%
# Q1, Create a vehicle class with an init method having instance variables as name_of_vehicle, max_speed
# and average_of_vehicle.

class Vehicle:
    def __init__(self, name_of_vehicle, max_speed, average_of_vehicle):
        self.name_of_vehicle = name_of_vehicle
        self.max_speed = max_speed
        self.average_of_vehicle = average_of_vehicle

    def return_vehicle_details(self):
        return self.name_of_vehicle, self.max_speed, self.average_of_vehicle
komal = Vehicle("Hyundai", 150, 60)
print(komal.return_vehicle_details())

#Q2. Create a child class car from the vehicle class created in Que 1, which will inherit the vehicle class.
#Create a method named seating_capacity which takes capacity as an argument and returns the name of
#the vehicle and its seating capacity.

class Car(Vehicle):
    def seating_capacity(self, capacity):
        return f"{self.name_of_vehicle} - Seating Capacity: {capacity}"


komal = Vehicle("Hyundai", 150, 60)
print(komal.return_vehicle_details())

child_test_obj = Car("Toyota", 180, 60)
print(child_test_obj.return_vehicle_details())
print(child_test_obj.seating_capacity(5))
#Q3. What is multiple inheritance? Write a python code to demonstrate multiple inheritance.
#multiple inheritence is like class 1 is containinng class 2 ans class 2 is containing class 3
class class1:
    def test_class1(self):
        return "this is my meth of class 1"
class class2(class1):
    def test_class2(self):
        return "this is my meth of class 2"
class class3(class2):
    pass
komal=class3()
print(komal.test_class1())
print(komal.test_class2())

#Q4. What are getter and setter in python? Create a class and create a getter and a setter method in this
#class.
"""getters and setters are methods used to access and modify the attributes of a class. They provide controlled access to the class's variables, allowing you to enforce any necessary constraints or logic.

A getter method, also known as an accessor method, is used to retrieve the value of an attribute. It provides read-only access to the attribute, usually by returning its value. Getter methods are useful when you want to perform some additional operations or validations before returning the attribute value.

A setter method, also known as a mutator method, is used to modify the value of an attribute. It provides write-only access to the attribute, allowing you to set a new value. Setter methods are helpful when you want to enforce specific rules or validations before updating the attribute value."""
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def set_name(self,name):
        set.name=name()
    def get_name(self):
        return self.name
    def set_age(self,age):
        self.age=age
    def get_age(self):
        return self.age
rohan=person("vishnu",18)
print(rohan.get_name(),rohan.get_age())
#Q5.What is method overriding in python? Write a python code to demonstrate method overriding.
#Method overriding in Python refers to the ability of a subclass to provide a different implementation of a method that is already defined in its parent class. The subclass overrides the method of the parent class to modify its behavior or add additional functionality.
class HumanNature:
    def human_behaviour(self):
        print("Normal behavior")

    def naughty_behaviour(self):
        print("Kind of behavior")

    def rude_behaviour(self):
        print("Rude behavior")

    def polite_behaviour(self):
        print("Polite behavior")


class ChildNature(HumanNature):
    def naughty_behaviour(self):
        print("Mischievous behavior")

    def polite_behaviour(self):
        print("Respectful behavior")


human = HumanNature()
human.human_behaviour()
human.naughty_behaviour()
human.rude_behaviour()
human.polite_behaviour()

child = ChildNature()
child.human_behaviour()
child.naughty_behaviour()
child.rude_behaviour()
child.polite_behaviour()
# Out:
# ('Hyundai', 150, 60)
# ('Hyundai', 150, 60)
# ('Toyota', 180, 60)
# Toyota - Seating Capacity: 5
# this is my meth of class 1
# this is my meth of class 2
# vishnu 18
# Normal behavior
# Kind of behavior
# Rude behavior
# Polite behavior
# Normal behavior
# Mischievous behavior
# Rude behavior
# Respectful behavior
